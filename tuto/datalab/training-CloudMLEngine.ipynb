# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.13.1

# %%
# change these to try this notebook out
BUCKET = 'huiyi-sandbox'
PROJECT = 'huiyi-training'
REGION = 'us-central1'

# %%
import os
os.environ['BUCKET'] = BUCKET
os.environ['PROJECT'] = PROJECT
os.environ['REGION'] = REGION

# %%
# %%bash
# gcloud config set project $PROJECT
# gcloud config set compute/region $REGION
# Out:
# Updated property [core/project].
# Updated property [compute/region].

# %%
# %%bash
# if ! gsutil ls | grep -q gs://${BUCKET}/; then
#   gsutil mb -l ${REGION} gs://${BUCKET}
# fi

# %%
# %bash
gsutil ls gs://${BUCKET}/preproc/*-00000*
# Out:
# gs://huiyi-sandbox/preproc/eval.csv-00000-of-00001
# gs://huiyi-sandbox/preproc/train.csv-00000-of-00001

# %% [markdown]
# Training on Cloud ML Engine requires:
#
# 1. Making the code a Python package
# 2. Using gcloud to submit the training code to Cloud ML Engine

# %%
# %writefile tuto/trainer/task.py
import argparse
import json
import os

from . import model

import tensorflow as tf

if __name__ == '__main__':
    parser = argparse.ArgumentParser()
    parser.add_argument(
        '--bucket',
        help = 'GCS path to data. We assume that data is in gs://BUCKET/preproc/',
        required = True
    )
    parser.add_argument(
        '--output_dir',
        help = 'GCS location to write checkpoints and export models',
        required = True
    )
    parser.add_argument(
        '--batch_size',
        help = 'Number of examples to compute gradient over.',
        type = int,
        default = 128
    )
    parser.add_argument(
        '--job-dir',
        help = 'this model ignores this field, but it is required by gcloud',
        default = 'junk'
    )
 
    ## TODO 1: add the new arguments here 
    parser.add_argument(
        '--train_examples',
        help = 'Number of examples (in thousands) to run the training job over. If this is more than actual # of examples available,\
        it cycles through them. So specifying 1000 here when you have only 100k examples makes this 10 epochs.',
        type = int,
        default = 5000
    )    
    parser.add_argument(
        '--pattern',
        help = 'Specify a pattern that has to be in input files. For example 00001-of will process only one shard',
        default = 'of'
    )
    parser.add_argument(
        '--eval_steps',
        help = 'Positive number of steps for which to evaluate model. Default to None, \
        which means to evaluate until input_fn raises an end-of-input exception',
        type = int,       
        default = None
    )
        
    ## parse all arguments
    args = parser.parse_args()
    arguments = args.__dict__

    # unused args provided by service
    #arguments.pop('job_dir', None)
    arguments.pop('job-dir', None)

    ## assign the arguments to the model variables
    output_dir = arguments.pop('output_dir')
    model.BUCKET     = arguments.pop('bucket')
    model.BATCH_SIZE = arguments.pop('batch_size')
    model.TRAIN_STEPS = (arguments.pop('train_examples') * 1000) / model.BATCH_SIZE
    model.EVAL_STEPS = arguments.pop('eval_steps')    
    print ("Will train for {} steps using batch_size={}".format(model.TRAIN_STEPS, model.BATCH_SIZE))
    model.PATTERN = arguments.pop('pattern')

    # Append trial_id to path if we are doing hptuning
    # This code can be removed if you are not using hyperparameter tuning
    output_dir = os.path.join(
        output_dir,
        json.loads(
            os.environ.get('TF_CONFIG', '{}')
        ).get('task', {}).get('trial', '')
    )
    
    print("outpur_dir: {}".format(output_dir))
    
    # Run the training job
    model.train_and_evaluate(output_dir)
# Out:
# Overwriting tuto/trainer/task.py

# %%
# %writefile tuto/trainer/model.py
import shutil
import numpy as np
import tensorflow as tf

tf.logging.set_verbosity(tf.logging.INFO)

BUCKET = None  # set from task.py
PATTERN = 'of' # gets all files

# Determine CSV, label, and key columns
CSV_COLUMNS = 'SALE_PRICE,BOROUGH,BLOCK,ZIP_CODE,key'.split(',')
LABEL_COLUMN = 'SALE_PRICE'
KEY_COLUMN = 'key'

# Set default values for each CSV column
DEFAULTS = [[600000.0], ['1'], [1418.0], [10065.0],['nokey']]

# Define some hyperparameters
TRAIN_STEPS = 10000
EVAL_STEPS = None
BATCH_SIZE = 128

# Create an input function reading a file using the Dataset API
# Then provide the results to the Estimator API
def read_dataset(prefix, mode, batch_size=128):
    def _input_fn():
        def decode_csv(value_column):
            columns = tf.decode_csv(value_column, record_defaults=DEFAULTS)
            features = dict(zip(CSV_COLUMNS, columns))
            label = features.pop(LABEL_COLUMN)
            return features, label
        
        # Use prefix to create file path
        file_path = 'gs://{}/preproc/{}*{}*'.format(BUCKET, prefix, PATTERN)
        
        # Create list of files that match pattern
        file_list = tf.gfile.Glob(file_path)

        # Create dataset from file list
        dataset = (tf.data.TextLineDataset(file_list)  # Read text file
                    .map(decode_csv))  # Transform each elem by applying decode_csv fn
              
        if mode == tf.estimator.ModeKeys.TRAIN:
            num_epochs = None # indefinitely
            dataset = dataset.shuffle(buffer_size = 10 * batch_size) #melanger les donnees
        else:
            num_epochs = 1 # end-of-input after this
 
        dataset = dataset.repeat(num_epochs).batch(batch_size)
  
        return dataset.make_one_shot_iterator().get_next()
    return _input_fn


#Create feature columns for estimator
def make_feature_cols():
    # Define column types
    INPUT_COLUMNS = \
        [\
            tf.feature_column.categorical_column_with_vocabulary_list('BOROUGH', ['1', '2', '3', '4', '5']),
            tf.feature_column.numeric_column('BLOCK'),
            tf.feature_column.numeric_column('ZIP_CODE')
        ]
    
    return INPUT_COLUMNS


# Create serving input function to be able to serve predictions later using provided inputs
def serving_input_fn():
    feature_placeholders = {
        'BOROUGH': tf.placeholder(tf.string, [None]),
        'BLOCK': tf.placeholder(tf.float32, [None]),
        'ZIP_CODE': tf.placeholder(tf.float32, [None]),
        KEY_COLUMN: tf.placeholder_with_default(tf.constant(['nokey']), [None])
    }

    features = {
        key: tf.expand_dims(tensor, -1)
        for key, tensor in feature_placeholders.items()
    }
    
    return tf.estimator.export.ServingInputReceiver(features, feature_placeholders)


# create metric for hyperparameter tuning
def my_rmse(labels, predictions):
    pred_values = predictions['predictions']
    return {'rmse': tf.metrics.root_mean_squared_error(labels, pred_values)}
  
#create estimator to train and evaluate
def train_and_evaluate(OUTDIR):
    tf.summary.FileWriterCache.clear() # ensure filewriter cache is clear for TensorBoard events file
    #Linear Regression with tf.Estimator framework
    shutil.rmtree(OUTDIR, ignore_errors = True) # start fresh each time

    tf.logging.set_verbosity(tf.logging.INFO)

    #create model of linear regression
    #estimator = tf.estimator.LinearRegressor(feature_columns = make_feature_cols())
    estimator = tf.estimator.LinearRegressor(
                       model_dir = OUTDIR,
                       feature_columns = make_feature_cols())
    
    EVAL_INTERVAL = 300 # seconds

    ## set the save_checkpoints_secs to the EVAL_INTERVAL
    run_config = tf.estimator.RunConfig(save_checkpoints_secs = EVAL_INTERVAL,
                                        keep_checkpoint_max = 3)

    # illustrates how to add an extra metric
    estimator = tf.contrib.estimator.add_metrics(estimator, my_rmse)
    # for batch prediction, you need a key associated with each instance
    estimator = tf.contrib.estimator.forward_features(estimator, KEY_COLUMN)

    #Set the third argument of read_dataset to BATCH_SIZE and set max_steps to TRAIN_STEPS
    train_spec = tf.estimator.TrainSpec(
        input_fn = read_dataset('train', tf.estimator.ModeKeys.TRAIN, BATCH_SIZE),
        max_steps = TRAIN_STEPS)
    
    #exporter = tf.estimator.LatestExporter('exporter', serving_input_fn, exports_to_keep=None)
    exporter = tf.estimator.LatestExporter('exporter', serving_input_fn)

    # Lastly, set steps equal to EVAL_STEPS
    eval_spec = tf.estimator.EvalSpec(
        input_fn = read_dataset('eval', tf.estimator.ModeKeys.EVAL, 2**15),  # no need to batch in eval
        steps = EVAL_STEPS,
        start_delay_secs = 60, # start evaluating after N seconds
        throttle_secs = EVAL_INTERVAL,  # evaluate every N seconds
        exporters = exporter)

    tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)
# Out:
# Overwriting tuto/trainer/model.py

# %% [markdown]
# make sure it works standalone. (Note the --pattern and --train_examples lines so that I am not trying to boil the ocean on my laptop).

# %% [markdown]
# Test en locale avant de deployer dans Cloud ML Engine

# %%
# %bash
echo "bucket=${BUCKET}"
rm -rf tuto_trained

export PYTHONPATH=${PYTHONPATH}:${PWD}/tuto

python -m trainer.task \
  --bucket=${BUCKET} \
  --output_dir=tuto_trained \
  --job-dir=./train_tmp \
  --pattern="00000-of-" --train_examples=1 --eval_steps=1
# Out:
# bucket=huiyi-sandbox
# Will train for 7 steps using batch_size=128
# outpur_dir: tuto_trained/
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
# /usr/local/envs/py2env/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_num_ps_replicas': 0, '_keep_checkpoint_max': 5, '_task_type': 'worker', '_global_id_in_cluster': 0, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f7410fc24d0>, '_model_dir': 'tuto_trained/', '_protocol': None, '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_device_fn': None, '_experimental_distribute': None, '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_evaluation_master': '', '_eval_distribute': None, '_train_distribute': None, '_master': ''}
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_num_ps_replicas': 0, '_keep_checkpoint_max': 5, '_task_type': 'worker', '_global_id_in_cluster': 0, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f74241efd90>, '_model_dir': 'tuto_trained/', '_protocol': None, '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_device_fn': None, '_experimental_distribute': None, '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_evaluation_master': '', '_eval_distribute': None, '_train_distribute': None, '_master': ''}
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_num_ps_replicas': 0, '_keep_checkpoint_max': 5, '_task_type': 'worker', '_global_id_in_cluster': 0, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f74241efe50>, '_model_dir': 'tuto_trained/', '_protocol': None, '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_device_fn': None, '_experimental_distribute': None, '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_evaluation_master': '', '_eval_distribute': None, '_train_distribute': None, '_master': ''}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# WARNING:tensorflow:From /content/.local/lib/python2.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /content/.local/lib/python2.7/site-packages/tensorflow/python/feature_column/feature_column_v2.py:2703: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /content/.local/lib/python2.7/site-packages/tensorflow/python/ops/lookup_ops.py:1137: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# 2019-04-26 07:42:13.862643: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-04-26 07:42:14.287070: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-04-26 07:42:14.307722: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x55bb1655b000 executing computations on platform Host. Devices:
# 2019-04-26 07:42:14.307796: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into tuto_trained/model.ckpt.
# INFO:tensorflow:loss = 2728995600000000.0, step = 1
# INFO:tensorflow:Saving checkpoints for 7 into tuto_trained/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-26T07:42:18Z
# INFO:tensorflow:Graph was finalized.
# WARNING:tensorflow:From /content/.local/lib/python2.7/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from tuto_trained/model.ckpt-7
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-04-26-07:42:19
# INFO:tensorflow:Saving dict for global step 7: average_loss = 68664520000000.0, global_step = 7, label/mean = 1393804.8, loss = 1.1743693e+18, prediction/mean = 12057.076, rmse = 8286405.5
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 7: tuto_trained/model.ckpt-7
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# WARNING:tensorflow:From /content/.local/lib/python2.7/site-packages/tensorflow/python/saved_model/signature_def_utils_impl.py:205: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Regression input must be a single string Tensor; got {'BOROUGH': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=string>, 'key': <tf.Tensor 'PlaceholderWithDefault:0' shape=(?,) dtype=string>, 'BLOCK': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>, 'ZIP_CODE': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'BOROUGH': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=string>, 'key': <tf.Tensor 'PlaceholderWithDefault:0' shape=(?,) dtype=string>, 'BLOCK': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>, 'ZIP_CODE': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from tuto_trained/model.ckpt-7
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: tuto_trained/export/exporter/temp-1556264539/saved_model.pb
# INFO:tensorflow:Loss for final step: 2053449200000000.0.

# %% [markdown]
# Once the code works in standalone mode, you can run it on Cloud ML Engine.
#
# Because this is on the entire dataset, it will take a while.  You can monitor the job from the GCP console in the Cloud Machine Learning Engine section.

# %%
# %bash
OUTDIR=gs://${BUCKET}/tuto/trained_model
JOBNAME=tuto_$(date -u +%y%m%d_%H%M%S)


# Removing gs://huiyi-sandbox/tuto/trained_model/model.ckpt-1174587.meta#1556197203437403...
# Removing gs://huiyi-sandbox/tuto/trained_model/model.ckpt-1406578.data-00000-of-00003#1556197799450599...
# Removing gs://huiyi-sandbox/tuto/trained_model/model.ckpt-1406578.data-00001-of-00003#1556197798953997...
# Removing gs://huiyi-sandbox/tuto/trained_model/model.ckpt-1406578.data-00002-of-00003#1556197798480829...
# Removing gs://huiyi-sandbox/tuto/trained_model/model.ckpt-1406578.index#1556197799882722...
# Removing gs://huiyi-sandbox/tuto/trained_model/model.ckpt-1406578.meta#1556197803578722...
# Removing gs://huiyi-sandbox/tuto/trained_model/model.ckpt-1562506.data-00000-of-00003#1556198199817566...
# Removing gs://huiyi-sandbox/tuto/trained_model/model.ckpt-1562506.data-00001-of-00003#1556198199321124...
# Removing gs://huiyi-sandbox/tuto/trained_model/model.ckpt-1562506.data-00002-of-00003#1556198198800826...
# Removing gs://huiyi-sandbox/tuto/trained_model/model.ckpt-1562506.index#1556198200346549...
# Removing gs://huiyi-sandbox/tuto/trained_model/model.ckpt-1562506.meta#1556198203976417...
# Removing gs://huiyi-sandbox/tuto/trained_model/model.ckpt-705422.data-00000-of-00003#1556195999448958...
# Removing gs://huiyi-sandbox/tuto/trained_model/model.ckpt-705422.data-00001-of-00003#1556195998925106...
# Removing gs://huiyi-sandbox/tuto/trained_model/model.ckpt-705422.data-00002-of-00003#1556195998464855...
# Removing gs://huiyi-sandbox/tuto/trained_model/model.ckpt-705422.index#1556195999899560...
# Removing gs://huiyi-sandbox/tuto/trained_model/model.ckpt-705422.meta#1556196002853530...
# Removing gs://huiyi-sandbox/tuto/trained_model/model.ckpt-942162.data-00000-of-00003#1556196599253495...
# Removing gs://huiyi-sandbox/tuto/trained_model/model.ckpt-942162.data-00001-of-00003#1556196598780267...
# Removing gs://huiyi-sandbox/tuto/trained_model/model.ckpt-942162.data-00002-of-00003#1556196598198512...
# Removing gs://huiyi-sandbox/tuto/trained_model/model.ckpt-942162.index#1556196599812078...
# Removing gs://huiyi-sandbox/tuto/trained_model/model.ckpt-942162.meta#1556196602432807...
# / [73/73 objects] 100% Done
# Operation completed over 73 objects.
# Job [tuto_190426_074358] submitted successfully.
# Your job is still active. You may view the status of your job with the command
#
#   $ gcloud ml-engine jobs describe tuto_190426_074358
#
# or continue streaming the logs with the command
#
#   $ gcloud ml-engine jobs stream-logs tuto_190426_074358

# %% [markdown]
# Monitor with TensorBoard

# %%
from google.datalab.ml import TensorBoard
TensorBoard().start('gs://{}/trained_model'.format(BUCKET))
# Out:
# <p>TensorBoard was started successfully with pid 5849. Click <a href="/_proxy/36049/" target="_blank">here</a> to access it.</p>
# 5849

# %% [markdown]
# stop the tensorboard after if you finish the monitor

# %%
for pid in TensorBoard.list()['pid']:
    TensorBoard().stop(pid)
    print('Stopped TensorBoard with pid {}'.format(pid))
# Out:
# Stopped TensorBoard with pid 5818
# Stopped TensorBoard with pid 5849

# %% [markdown]
# Hyperparameter tuning
#
# All of these are command-line parameters to my program. To do hyperparameter tuning, create hyperparam.xml and pass it as --configFile. This step will take up to 2 hours -- you can increase maxParallelTrials or reduce maxTrials to get it done faster. Since maxParallelTrials is the number of initial seeds to start searching from, you don't want it to be too large; otherwise, all you have is a random search.

# %%
# %writefile hyperparam.yaml
trainingInput:
  scaleTier: STANDARD_1
  hyperparameters:
    hyperparameterMetricTag: rmse
    goal: MINIMIZE
    maxTrials: 20
    maxParallelTrials: 5
    enableTrialEarlyStopping: True
    params:
    - parameterName: batch_size
      type: INTEGER
      minValue: 8
      maxValue: 218
      scaleType: UNIT_LOG_SCALE
# Out:
# Overwriting hyperparam.yaml

# %%
# %bash
OUTDIR=gs://${BUCKET}/tuto/hyperparam
JOBNAME=tuto_$(date -u +%y%m%d_%H%M%S)

echo $OUTDIR $REGION $JOBNAME
gsutil -m rm -rf $OUTDIR

gcloud ml-engine jobs submit training $JOBNAME \
  --region=$REGION \
  --module-name=trainer.task \
  --package-path=$(pwd)/tuto/trainer \
  --job-dir=$OUTDIR \
  --staging-bucket=gs://$BUCKET \
  --scale-tier=STANDARD_1 \
  --config=hyperparam.yaml \
  --runtime-version=$TFVERSION \
  -- \
  --bucket=${BUCKET} \
  --output_dir=${OUTDIR} \
  --eval_steps=10 \
  --train_examples=20000
# Out:
# gs://huiyi-sandbox/tuto/hyperparam us-central1 tuto_190426_090545
# jobId: tuto_190426_090545
# state: QUEUED
# Removing gs://huiyi-sandbox/tuto/hyperparam/#1556199469637474...
# Removing gs://huiyi-sandbox/tuto/hyperparam/1

# Removing gs://huiyi-sandbox/tuto/hyperparam/9/model.ckpt-246919.data-00000-of-00003#1556200535631837...
# Removing gs://huiyi-sandbox/tuto/hyperparam/9/model.ckpt-246919.data-00001-of-00003#1556200535170570...
# Removing gs://huiyi-sandbox/tuto/hyperparam/9/model.ckpt-246919.data-00002-of-00003#1556200534662043...
# Removing gs://huiyi-sandbox/tuto/hyperparam/9/model.ckpt-246919.index#1556200536215246...
# Removing gs://huiyi-sandbox/tuto/hyperparam/9/model.ckpt-246919.meta#1556200538818835...
# / [575/575 objects] 100% Done 30.63 objects/s ETA 00:00:00
# Operation completed over 575 objects.
# Job [tuto_190426_090545] submitted successfully.
# Your job is still active. You may view the status of your job with the command
#
#   $ gcloud ml-engine jobs describe tuto_190426_090545
#
# or continue streaming the logs with the command
#
#   $ gcloud ml-engine jobs stream-logs tuto_190426_090545

# %% [markdown]
# Repeat training
#
# This time with tuned parameters (note last line)

# %%
# %bash
OUTDIR=gs://${BUCKET}/tuto/trained_model_tuned
JOBNAME=tuto_$(date -u +%y%m%d_%H%M%S)

echo $OUTDIR $REGION $JOBNAME
gsutil -m rm -rf $OUTDIR

gcloud ml-engine jobs submit training $JOBNAME \
  --region=$REGION \
  --module-name=trainer.task \
  --package-path=$(pwd)/tuto/trainer \
  --job-dir=$OUTDIR \
  --staging-bucket=gs://$BUCKET \
  --scale-tier=STANDARD_1 \
  --runtime-version=$TFVERSION \
  -- \
  --bucket=${BUCKET} \
  --output_dir=${OUTDIR} \
  --train_examples=20000 --batch_size=35
# Out:
# gs://huiyi-sandbox/tuto/trained_model_tuned us-central1 tuto_190426_102141
# jobId: tuto_190426_102141
# state: QUEUED
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/#1556203045392936...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/checkpoint#1556203049623511...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/eval/#1556202324432895...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/eval/events.out.tfevents.1556202324.cmle-training-master-dfcc9cee3b-0-ljwgm#1556203054163982...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/events.out.tfevents.1556202309.cmle-training-master-dfcc9cee3b-0-ljwgm#1556203051183694...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/export/#1556202326953440...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/export/exporter/#1556202327295975...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/export/exporter/1556202325/#1556202333024935...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/export/exporter/1556202325/saved_model.pb#1556202333375410...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/export/exporter/1556202325/variables/#1556202333700574...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/export/exporter/1556202325/variables/variables.data-00000-of-00001#1556202334022351...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/export/exporter/1556202325/variables/variables.index#1556202334350998...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/export/exporter/1556202924/#1556202930916174...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/export/exporter/1556202924/saved_model.pb#1556202931371553...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/export/exporter/1556202924/variables/#1556202931933317...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/export/exporter/1556202924/variables/variables.data-00000-of-00001#1556202932363604...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/export/exporter/1556202924/variables/variables.index#1556202932708859...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/export/exporter/1556203054/#1556203061271573...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/export/exporter/1556203054/saved_model.pb#1556203061619206...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/export/exporter/1556203054/variables/#1556203061965827...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/export/exporter/1556203054/variables/variables.data-00000-of-00001#1556203062529146...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/export/exporter/1556203054/variables/variables.index#1556203062885168...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/graph.pbtxt#1556202312261160...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/model.ckpt-1.data-00000-of-00003#1556202317627853...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/model.ckpt-1.data-00001-of-00003#1556202317216303...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/model.ckpt-1.data-00002-of-00003#1556202316757993...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/model.ckpt-1.index#1556202318165623...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/model.ckpt-1.meta#1556202320783685...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/model.ckpt-470518.data-00000-of-00003#1556202917816435...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/model.ckpt-470518.data-00001-of-00003#1556202917180039...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/model.ckpt-470518.data-00002-of-00003#1556202916656405...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/model.ckpt-470518.index#1556202918367205...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/model.ckpt-470518.meta#1556202920917788...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/model.ckpt-571435.data-00000-of-00003#1556203047742900...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/model.ckpt-571435.data-00001-of-00003#1556203047255110...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/model.ckpt-571435.data-00002-of-00003#1556203046700720...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/model.ckpt-571435.index#1556203048218537...
# Removing gs://huiyi-sandbox/tuto/trained_model_tuned/model.ckpt-571435.meta#1556203050737367...
# / [38/38 objects] 100% Done
# Operation completed over 38 objects.
# Job [tuto_190426_102141] submitted successfully.
# Your job is still active. You may view the status of your job with the command
#
#   $ gcloud ml-engine jobs describe tuto_190426_102141
#
# or continue streaming the logs with the command
#
#   $ gcloud ml-engine jobs stream-logs tuto_190426_102141
